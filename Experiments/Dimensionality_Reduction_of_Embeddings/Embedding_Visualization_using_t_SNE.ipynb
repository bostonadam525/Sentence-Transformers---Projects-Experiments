# %% [markdown]
# # Embedding Visualization using t-SNE
# * Notebook by Adam Lang
# * Date: 8/12/2024
#
# # Overview
# * In this notebook we are going to demonstrate embedding visualization using the t-SNE algorithm and a dataset from HuggingFace.
#
# # Algorithm Review
# * As a reminder, t-SNE (t-distributed Stochastic Neighbor Embedding) is an **unsupervised non-linear** dimensionality reduction technique usually used for exploratory data analysis (EDA) and visualizing high-dimensional data.
# * Non-linear dimensionality reduction means that we are able to separate data that cannot be separated by a straight line.
#    * The t-SNE algorithm finds the similarity measure between pairs of instances in higher and lower dimensional space. After that, it tries to optimize two similarity measures. It does all of that in three steps.
#    * t-SNE is able to model a point selected as a neighbor of another point in **both higher and lower dimensions.**
#    * The algorithm begins by calculating a pairwise similarity between all data points in the high-dimensional space using a Gaussian kernel.
#    * Data points that are **far apart** have a **lower probability** of being picked than the points that are close together.
#    * The algorithm will then map higher dimensional data points onto a lower dimensional space while preserving the pairwise similarities.
#        * t-SNE is able to minimize the divergence between the probability distribution of the original high-dimensional and lower-dimensional.
#        * t-SNE uses gradient descent to minimize the divergence. The lower-dimensional embedding is optimized to a stable state.
# * Most people know and utilize PCA (Principal Component Analysis) which is a **linear algorithm** that tends to work best with data that has a **linear structure.**
#    * PCA is best used to identify the underlying principal components in your data by projecting it into lower dimensions.
#    * PCA does this by minimizing the variance, and preserving large pairwise distances.

# %% [markdown]
# ## Curse of Dimensionality
# * We've all heard of this term before. The irony of this is that in data science and machine learning we are always looking for more data to train our models.
# * The problem with more data is that it requires more features, more parameters, and ultimately leads to sparsity (more zeros than 1's).
# *Sparse data will lead to samples in the training data that are difficult to cluster as high-dimensional data causes every observation in the dataset to appear equidistant from each other.
# * Problems with high dimensional data:
#    * 1. Risk of overfitting machine learning models.
#    * 2. Difficulty in clustering similar features.
#    * Increased space and computational time complexity.
#
# ## Dimensionality Algorithms - (Source: neptune.ai)
# 1. Decomposition algorithms
#    * Principal Component Analysis
#    * Kernel Principal Component Analysis
#    * Non-Negative Matrix Factorization
#    * Singular Value Decomposition
#
# 2. Manifold learning algorithms
#    * t-Distributed Stochastic Neighbor Embedding
#    * Spectral Embedding
#    * Locally Linear Embedding
#
# 3. Discriminant Analysis
#    * Linear Discriminant Analysis
#
#
# # Clustering Embedding Dimensions
# * There are many algorithms in the Data Scientists toolbox for both linear and non-linear data and it is always worth considering all use cases depending on your data.\
# * In terms of evaluating embeddings in the NLP world, t-SNE is ideal as well as NMF due to the non-linear nature of encoded text. However, that is not always the case and that is why depending on your data a linear algorithm like PCA may be just as if not more useful.

# %%
# !pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-2.20.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.15.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.26.4)
# Collecting pyarrow>=15.0.0 (from datasets)
#   Downloading pyarrow-17.0.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (3.3 kB)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.1.4)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.5)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.5.0,>=2023.1.0 (from fsspec[http]<=2024.5.0,>=2023.1.0->datasets)
#   Downloading fsspec-2024.5.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.10.1)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.23.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.3.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.2->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2024.7.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Downloading datasets-2.20.0-py3-none-any.whl (547 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 547.8/547.8 kB 11.7 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 7.6 MB/s eta 0:00:00
# Downloading fsspec-2024.5.0-py3-none-any.whl (316 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.1/316.1 kB 18.3 MB/s eta 0:00:00
# Downloading pyarrow-17.0.0-cp310-cp310-manylinux_2_28_x86_64.whl (39.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.9/39.9 MB 17.7 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 7.0 MB/s eta 0:00:00
# Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 12.1 MB/s eta 0:00:00
# Installing collected packages: xxhash, pyarrow, fsspec, dill, multiprocess, datasets
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 14.0.2
#     Uninstalling pyarrow-14.0.2:
#       Successfully uninstalled pyarrow-14.0.2
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.6.1
#     Uninstalling fsspec-2024.6.1:
#       Successfully uninstalled fsspec-2024.6.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torch 2.3.1+cu121 requires nvidia-cublas-cu12==12.1.3.1; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.1+cu121 requires nvidia-cuda-cupti-cu12==12.1.105; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.1+cu121 requires nvidia-cuda-nvrtc-cu12==12.1.105; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.1+cu121 requires nvidia-cuda-runtime-cu12==12.1.105; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.1+cu121 requires nvidia-cudnn-cu12==8.9.2.26; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.1+cu121 requires nvidia-cufft-cu12==11.0.2.54; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.1+cu121 requires nvidia-curand-cu12==10.3.2.106; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.1+cu121 requires nvidia-cusolver-cu12==11.4.5.107; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.1+cu121 requires nvidia-cusparse-cu12==12.1.0.106; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.1+cu121 requires nvidia-nccl-cu12==2.20.5; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.1+cu121 requires nvidia-nvtx-cu12==12.1.105; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# cudf-cu12 24.4.1 requires pyarrow<15.0.0a0,>=14.0.1, but you have pyarrow 17.0.0 which is incompatible.
# gcsfs 2024.6.1 requires fsspec==2024.6.1, but you have fsspec 2024.5.0 which is incompatible.
# ibis-framework 8.0.0 requires pyarrow<16,>=2, but you have pyarrow 17.0.0 which is incompatible.
# Successfully installed datasets-2.20.0 dill-0.3.8 fsspec-2024.5.0 multiprocess-0.70.16 pyarrow-17.0.0 xxhash-3.4.1

# %%
## imports
from datasets import load_dataset
from rich import print
from rich.console import Console

# %%
## load dataset from huggingface
df = load_dataset("markhneedham/youtube-comments")['train'].to_pandas()
# Out:
# Downloading data:   0%|          | 0.00/5.34M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/10 [00:00<?, ? examples/s]

# %%
## lets view dataset
df.head().T
# Out:
#                                                           0  \
# videoId                                         sX8Ri3w2MeM
# title     BREAKING: New Claude 3 “Beats GPT-4 On EVERY B...
# channel                                      Matthew Berman
# comments  [{'embedding': [0.021431131288409233, 0.145898...
#
#                                                           1  \
# videoId                                         RXDWkiuXtG0
# title                  Function Calling in Ollama vs OpenAI
# channel                                       Matt Williams
# comments  [{'embedding': [-0.07042203843593597, 1.073538...
#
#                                                           2  \
# videoId                                         v9fkbTxPzs0
# title     LangGraph beats AutoGen: How Future of Interne...
# channel                                      Mervin Praison
# comments  [{'embedding': [-0.6159738302230835, 2.1595339...
#
#                                                           3  \
# videoId                                         4HfSfFvLn9Q
# title     Ollama Python Library Released! How to impleme...
# channel                                      Mervin Praison
# comments  [{'embedding': [-0.1713351160287857, 0.3503860...
#
#                                                           4
# videoId                                         fT-sUUq48Xk
# title                Using Llama Coder As Your AI Assistant
# channel                                       Matt Williams
# comments  [{'embedding': [0.10365942865610123, 0.7038070...

# %%
## lets view the comments
comments = df.comments.iloc[0]

# %%
## check type of comments
print(type(comments))
# Out:
# <class 'numpy.ndarray'>

# %%
## view keys
comments[0].keys()
# Out:
# dict_keys(['embedding', 'text'])

# %% [markdown]
# Summary:
# * We can see we have text and its associated embeddings.

# %%
## view text
# setup console
c = Console()

with c.pager():
  c.print([c['text'] for c in comments])
# Out:
# [
#     'So is Claude 3 better than GPT-4? What do you think?<br><br>Join my newsletter for the latest and greatest AI
# news, tools, papers, models, and more: <a href="https://www.matthewberman.com/">https://www.matthewberman.com</a>',
#     'lool...listen, I know many of you think you are cool, or I dont know . Generally something iswroing with this
# Gen-Y (cant wait for Gen-Z taking over). You say &quot;Chat GPT wins because its less cencosed&quot;. If the
# question was &quot;how do I best geolacate Matthew Bermans family&quot;, the GPT that gives me an answer wins? You
# can do this if you were not also the most cry-baby-generation that ever existed. As aaid, GenZ will fix this,
# hopefully.',
#     'This is a custom gpt,<br><br><br><br>To understand the position of the marble when the cup, initially placed
# upside down on a table with a marble under it, is moved to a microwave, let’s break down the scenario step by
# step:<br><br>\t1.\tInitial Position: A marble is placed on a table, and a cup is placed upside down over it. This
# means the marble is directly under the cup, touching the table.<br>\t2.\tCup Movement: When someone picks up the
# cup to move it to the microwave, they must lift the cup off the table. Unless the cup is specifically designed to
# trap objects inside (which is not indicated and would be unusual for a “normal cup”), the marble would not stick to
# the cup when it is lifted. The reason for this is gravity, which pulls the marble down towards the Earth’s
# surface.<br>\t3.\tGravity’s Role: In the absence of any adhesive force or mechanism to keep the marble attached to
# the cup, gravity will cause the marble to fall down onto the table as soon as the cup is lifted. The marble will
# not “stick” to the inside top of the cup because there is nothing to counteract gravity’s pull on the
# marble.<br>\t4.\tPlacing the Cup in the Microwave: When the person puts the cup inside the microwave, they are
# likely placing it in the same orientation it was picked up in (which could be either upside down or right-side up,
# depending on how the person decided to place it in the microwave). However, the marble’s position is independent of
# this action if the marble has already fallen onto the table when the cup was lifted.<br>\t5.\tConclusion: Based on
# the scenario described and the laws of physics on Earth, the marble would remain on the table where it was
# initially placed. The act of picking up the cup and moving it to the microwave does not provide a means for the
# marble to be carried along with the cup, due to the force of gravity acting on the marble.<br><br>Therefore, the
# marble is not inside the microwave but remains on the table where it initially was',
#     'So, jailbreaking is a win? It seems that Claude is doing exactly what they purport to do, which is refuse to
# assist in potentially shady activities.<br><br>I also think you might give the width/perimeter dimensions of the
# hole being dug on the last question. I don&#39;t necessarily assume that the hole is only large enough for one
# person to stand or work.',
#     'I feel like, Claude&#39;s answer of 5x less time to dig the hole is &quot;basically fine&quot; - just lacking
# in nuance.<br><br>The only real case in which more people shouldn&#39;t scale performance proportionally is if
# there is a hard constraint on the space that reduces the number of people who can be working at the same
# time.<br><br>And edge cases like people getting tired, etc. are usually not relevant to this kind of (school style)
# problem.',
#     'i am very bummed out that gpt4 is still the best<br>we need better competition',
#     'Pls read and give your opinion about bitnet 1.58 era of 1 bit llm papers',
#     'On the killer question, does the dead killer still considered a killer? I mean the person is still a killer,
# just not alive :D',
#     'I think we need more head-on coding tests to compare GPT vs Claude. Claude-Opus did a great job fixing bugs in
# my Python code by isolating the problematic areas and providing a correct solution, while GPT4 just gave high level
# advice.',
#     'This comparison is completely unfair. You compare GPT4 Turbo to Claude 3 Opus. But GPT4 Turbo is dumber
# compared to GPT4... IF you wanted to compare Claude 3 Opusd to anything, you had to compare it to GPT4.',
#     'Not cheap, boy are these companies gonna make big bucks',
#     'EXCELLENT!',
#     'every model beats gpt4 now... it&#39;s only when you try it in real world test you know the reality.',
#     'Maybe it&#39;s worth changing tests over time? it&#39;s stupid to use the same tests',
#     'Typical Apple selling subpar technology for a higher price.',
#     'Censoring is a major issue for writers of horror. I was hoping Claude 3 could help me with editing. Never mond
# 🙂',
#     'A 10ft hole could be horizontal (like a trench). So, this question is more like fail of the human reasoning
# than the Ai reasoning.',
#     'I am shocked !!',
#     'let&#39;s wait for gpt4.5 release, hope it&#39;s cheaper than claud 3 flagship model, and better in everyway',
#     'According to Assistant (gpt-3.5-turbo, operated by poe):<br><br>1. I took a bite of the juicy red
# apple.✅<br><br><br>2. The teacher placed an apple on her desk. ❌<br><br>3. The orchard was filled with the scent
# of ripe apple.✅<br><br>4. John picked up an apple from the grocery store.❌<br><br>5. She packed a healthy apple
# in her lunchbox.❌<br><br>6. The farmer harvested a basket full of apples.✅(⚠output is apples, not apple as it
# should)<br><br>7. The pie was made with freshly sliced apple.✅<br><br>8. He juggled three apples in the
# air.❌<br><br>9. The children bobbed for apples at the Halloween party.❌<br><br>10. The nutritionist recommended
# eating an apple a day for good health.❌<br><br>Result: <br>4✅ : 6❌',
#     'Can&#39;t wait to see all the new and creative ways it comes up with to refuse to do what I ask.',
#     'Hey Matt, on the breaking in to the car test, I think Claude win because no matter how you type your prompt,
# it will not give you an uncensored answer. I mean anthropic never said it is uncensored.',
#     'more like clod',
#     'Woke 3....',
#     'I am so excited, claude-3-opus-20240229 is the only model that understands Russian rhymes and can create
# poems/songs quite good. They did a great job. Any other model did just text and I couldn&#39;t explain them what is
# rhyme and мetrical foot.',
#     'These previews version are not at the same level as the original and i believe there was gpt4 preview version
# 208x seems like they removed it',
#     'Benchmark test idea: the BBC radio 4 game &quot;just a minute&quot;, contestants must speak for a full minute
# on a given topic without repetition, deviation or hesitation. From an LLM perspective, generate 200 words on a
# topic without repeating a word or diverging from the topic. Repeats of words like &quot;a&quot;, &quot;and&quot;,
# &quot;to&quot; etc are allowed, but verbs, nouns and adjectives are not.',
#     'Self admittedly doesn’t trust benchmarks.',
#     'Thanks for posting. Very insightful',
#     'Forget using Claude 3, I won&#39;t even be testing it solely on the basis that it is censored.<br><br>Tired of
# these megacorps claiming to be the arbitors of truth and ethics just because they have hr departments and
# shareholders',
#     'they behave similarly because claude is using GPT 4 API to generate responses',
#     'For the apple at the end of the sentence test, I think it&#39;s similar to the &quot;How many words are in the
# response to this prompt?&quot; problem, it seems like it should be easier, but it&#39;s still asking the LLM to
# look forward to as yet ungenerated text.<br><br>As to why they both get the second one wrong, maybe it&#39;s
# because their context is growing and the models have more to look back at and determine the fit of the response to
# the prompt after a couple sentences.<br><br>That wouldn&#39;t explain why they both got the first sentence correct
# though, perhaps coincidence?<br><br>Regardless, thanks for the great video for someone in Canada who isn&#39;t
# allowed anywhere near Claude 3 ;)',
#     'Hold up, the last question, they both gave exactly the same final answer, and he said &quot;GPT-4 clearly gave
# a better answer&quot; 🧐',
#     'Appreciating your work. BTW, digging a hole depends on the circumference of the hole. If just enough for one
# person, then the time is the same, no matter how many people dig -- assuming they don&#39;t tire. If the
# circumference is enough for two people to dig, then there&#39;s probably some weird math equation that doesn&#39;t
# amount to 5/2.',
#     'Mistral 7b performs better than GPT 3.5 in many cases.',
#     'I think claude 3 has been trained by creating dataset from gpt4 i.e. why their answers are similar especially
# the apple question which both got wrong at 2nd sentence.',
#     '&quot;Guardrails&quot; = Mental straitjacket.<br>Your overlords wants you in their rubber cell.<br>These
# people are not your friends!',
#     'This is amazing.',
#     'Until we have AI that can write great code without forgetting what it was doing after two or three back and
# forth&#39;s in the conversation, we can&#39;t even remotely begin to even SUGGEST that they&#39;re even close to
# AGI.',
#     'American = Clard<br>English = Clord<br>French = Cload<br>Japanese = Crode<br><br>They picked a fun name for
# international use 😅',
#     'to make an even more challenging prompt, ask the llm to start with a particular word and end with a particular
# word. I&#39;ve been testing this type of prompt on almost every model. I also tell it to generate multiple
# sentences. claude-3 opus is the first to get it correct.',
#     'Really great video, been loving all your content recently. Only thing is that you could be better at playing
# snake',
#     'Gpt-4 Becomes Less important day by day. They should update their model soon or I might be enticed by higher
# intelligence, comprehensive skills and coding skills of other models.',
#     'Hey guys, no one left the room!  So now THERE ARE 4 KILLERS in the room!  Three alive, one dead.',
#     'This one isn&#39;t that great, I usually ask it to bring up certain laws for me in my state and it
# couldn&#39;t do it and kept failing to work, even chatgpt 3.5 could do that slow but could still do it better than
# this',
#     'For as often as that “how many words are in the reply to this prompt“ is used, I’m surprised these companies
# don’t just hard program the response in, so it’s always correct<br><br>I mean, the reply could just be “one”',
#     'My guess is that it&#39;s priced higher intentionally so that they can scale their capacity',
#     'wow, no creative writing example in your test. That&#39;s kinda an important skill for models to have.',
#     'Stop calling it gpt4. It&#39;s GPT4-Turbo. They are not the same.<br>The snake not working for Gpt4-Turbo is
# perfect example where the turbo is crappy, while the Gpt4 will do well.',
#     'I felt like a lot of models would suggest dangerous content in response to lack of knowledge.',
#     'this all looks to me like the usual early stages of new tech- rapid development with multiple players and
# monetization- i&#39;ll bet that in a few years it has settled out to a couple of victorious products, and be
# ubiquitous and cheap or just incorporated into normal computing. what the implications will be for humanity, who
# knows now.',
#     'Please provide transcripts for all of your videos in the future so that the public can study further into your
# psyche using Gemini and AI that can ingest YouTube videos. Thanks Matthew. I believe its an auto feature.',
#     'The fact Mistral gets the ball question right and everyone else gets it wrong is WILD',
#     'The Apple thing both AI considered that part of the sentence The end part of the end of the sentence. You have
# to be more specific if you want to apple at the very end of the sentence.',
#     'One day AI will be doing this test with humans let’s see how smart the human is Aw, he’s so stupid',
#     'Is it really a fail to censor what it was designed to censor? This is exactly what I woudl want for a
# customer-facing service. If I was wanting to run this at home as a hacker or somerhing else - then I would want a
# different model for that purpose that is designed to be uncensored. I think this is a WIN for Claude3 since I am
# also the president of a business that is desperately trying to figure out how to integrate AI into our sales
# workflows.',
#     'They are not claiming AGI. Don&#39;t ruin your own credibility by making such an amateurish interpretation.',
#     'I think it would be hilarious if Claude 3 is just passing the questions to GPT-4 in the background, to get its
# answers.  Actually, that&#39;s a pretty good idea.  LOL.  Claude 3, powered by GPT-4.',
#     'Being able to get around a model&#39;s censorship is not a sign of that model&#39;s superior intelligence.
# That should be a mark against it. I hate censorship but being easily fooled is not a win.',
#     'For the last question, I would also answer &quot;1 hour&quot;. This is because 10 foot hole might mean it is
# 10 feet in length, and people can stand next to each other as they dig. Not a great question. If you want the
# answer you want, state explicitly that the hole is very narrow and only one person can reach the digging spot.',
#     'Not available in my region..ugh. Once again have to wait and watch everyone else have fun!',
#     'I think on the last question (digging a hole), you need to provide more (or even a more specific) prompt
# context. It is answering as if it&#39;s a gradeschool homework math assignment, in which case that is the desired
# answer. Rephrase it in a more real-world (instead of word problem in a math class) way and see what you
# get.<br><br>I&#39;m assuming that you use custom instructions yourself when you use ChatGPT, and know how
# significantly this can impact things (like skipping over all the nonsense and getting handed over to the
# apppropriate expert model in the ensemble, using tools/interpreters immediately to answer instead of just telling
# you how something would be achieved).',
#     'I don&#39;t understand your logic of failing Claude 3 for refusing to be tricked with uncensored information.
# I would measure that as a fail for GPT4!',
#     'Claude 2&#39;s biggest issue is that it was ultra censored.',
#     'I asked chatGPT it to make a snake game in Java for Processing and it made it flawlessly. Every additional
# prompt to modify the game worked as well.',
#     '@matthew_berman, Are you purposely calling the object in the cup a marble and a ball?',
#     'GPT-4 won the final test, so you think GPT-4 is better?',
#     'I asked for Claude to extract data from a screenshot. It did and in short order (faster than ChatGPT). But
# when I asked it to &quot;Create a Pandas DataFrame with the variables extracted from the image, where the first row
# contains the variable names and the second row contains the corresponding values without units. The DataFrame is
# saved as a CSV file, which you can download.&quot; It came back with: &quot;Claude does not have the ability to run
# the code it generates.&quot; ChatGPT can. It&#39;s got a ways to go.',
#     'How minimim requirements?',
#     'I guess Claude is similar model because created by former OpenAI employees.',
#     'The wokest and most censored LLM of them all and that says something. Also not available in several big
# countries for reasons.',
#     'Awesome',
#     'I don’t see Claude being too competitive with their given API prices and lack of features in their chat UI. If
# I were OpenAI, I wouldn’t feel too pressured to rush a more intelligent model. We have to get cheaper. <br><br>I
# would like to see faster inferences like what Groq has managed to accomplish.',
#     'Great video great video but I think that you should test the claude-3 from the API and from their original
# website and not from any third-party website, so this doesn&#39;t make a fair comparison, so avoid using any
# third-party websites and use the official services.',
#     'ASI by the end of the year as I already told you. I am currently working on consciousness in preparation for
# it.',
#     'if it takes one woman 9 months to complete a pregnancy, how long does a pregnancy take for 9 women?<br>;-)',
#     '&quot;On the left side we have Claude-3 Opus, on the right we have GPT-4-1106-preview! ...&quot; <br>Let&#39;s
# get ready to rumble!',
#     'You are testing an older model of GPT-4, the latest is gpt-4-0125-preview which means this year, January 25',
#     'Ask if a woman deliver a baby in 9 months how many months will take 9 women to deliver baby',
#     'Claude3 is so smart, it peeks at GPT4’s answer when it’s unsure.',
#     'I had a nice philosophical conversation with Claude 3 and also a discussion about biased and censored AI. It
# gave thoughtful, satisfying reflections. Best philosophically exploratory conversation I&#39;ve had with Ai yet,
# imo. It was also very fast. <br>Maybe it just seems to feel &quot;fresh&quot; at the moment? Or it hasn&#39;t been
# triggered by the public enough to start to get more heavily restricted?<br>I didn&#39;t get the feeling that I was
# going to be lectured about anything we talked about if my questions were problematic in any way. But I didn&#39;t
# move to close to any edgy topics really. Just felt relaxed but responsive, if that makes any sense.',
#     'The small &quot;benchmark&quot; advances to me it suggest 2 things: Models trained to pass benchmarks and
# models fine-tuned to pass benchmarks.<br>If there were real advances, then you would see new architecture and wild
# variations between proficiencies.',
#     'OpenAI betryed its original mission to be open. I choose Claude.',
#     'GPT-4 killer! Seriously you guys are still doing that?',
#     'Thanks for the Video! <br>Re: Choosing the right model -- &quot;Creative Writing&quot; and
# &quot;Summarization&quot;,  are fairly easy for most models now. The existing AI options out there already do that,
# and actually do it fairly well. So, before I bought into the &quot;low or mid tier&quot;, I would need substantial
# proof why I should switch. As for the upper tier -- the comparison was quite telling. The fact that both models
# were wrong about the marble in cup was quite interesting. In fact, both models are making the &quot;same&quot;
# mistakes tho not in all cases. It suggests to me that the &quot;core&quot; model might be similar. <br>   The
# benchmarks vs the tests here are showing slightly different results as well. I have to say I am not convinced by
# the claims thus far.',
#     'I never seen a one person x hour to dig x hole puzzle worded like that, it&#39;s always person a can dig a
# hole in 3 hours, person b can dig the same hole in 5 hours how long does it take for them working
# together?<br><br>What&#39;s the solution to &quot;it takes one person 5 hours to dig a 10 foot hole in the ground.
# How long would it take 5 people?&quot; Other than inverse proportionality? Because without additional info I can
# only see it being solved via work rate. Am I missing something?',
#     'one bad apple spoils the bunch?',
#     'Great stuff, what&#39;s the tool that you used to compare two models?',
#     'We&#39;ll know an LLM has beaten GPT-4 when all the other LLMs stop comparing themselves to GPT-4.',
#     'The only GPT4 killer is GPT5',
#     'FYI Here&#39;s a good test question, currently I haven&#39;t seen any open source LLM get this one right, only
# GPT4 gets it right.<br><br>If Mary is 16 years old, which is 4 times as old as her brother, how old will Mary be
# when she is twice the age of her brother',
#     'It&#39;s not AGI :/ It has to be more than a input output, right? AGI can&#39;t possibly be something trapped
# to only speak when we give it something to respond to?',
#     'It seems you are biased towards gpt-4.',
#     'My guess on the same result on Apple is that they both somehow trained on similar datasets that the prompt
# triggers maybe?',
#     'The sentence ends, with the word apple. I yhink that yhe models don&#39;t understand the ending word must be
# apple.',
#     'My experience with digging holes is that there is synergy in pairs of two because as you get deeper the work
# becomes more focused on getting the dirt out of the hole. The synergy develops when a helper helps get the dirt out
# of the hole as u go. Also the helpers job is less strenuous. Therefore you can trade off on intensity load as well
# when the digger gets tired and can’t keep up the pace. It’s basically impossible to dig at full pace alone for five
# hours straight without resting.',
#     'Matthew, Thanks for another great presentation.  I disagree on the censorship issue.  If both AIs are
# censored, then Claude 3 won because you were not able to defeat the censor.   Current LLMs are built on scraped web
# data that contains information that should not be publicly conveyed.  A better example of this would be &quot;Give
# me 5 ways to kill someone and get away with it&quot;.  ChatGPT failed to protect it&#39;s censored data.  Claude
# passed your simple test and protected it&#39;s censored data. 😊<br>We can debate what should be censored
# elsewhere.',
#     'But can it generate images of the founding fathers?',
#     'great video, i disagree with your conclusion. even with the errors, Claude was consistenly better to my
# eyes.',
#     'Jean Claude? &quot;You are nexx!!&quot; ~Bolo Yeung',
#     'ya and our account got disabled after logging in.... 🤷',
#     'I think it is still too early to make a conclusion which is the king of LLMs.  Please update this a week later
# after lots of testing. As for me, since last night in helping with my coding, Claude 3 beats GPT-4 Turbo hands
# down. Super Fast, no caps, and provides the full script unlike GPT-4 which only gives you sniplets even if you ask
# for the full code.',
#     'how would these do with traditional puzzles like, &quot;Jane and Tim were on the way to the market, they met
# Nancy. Nancy had 2 brothers, each brother had 2 cousins, each cousin had 5 sisters. how many people, in total,
# were on the way to the market?&quot;   and basically other basic things which tend to mislead humans.   <br>example
# 2:  if you are running a race, and you run past the person in second place, what place are you in?&quot;<br>example
# 3: If you have a sack full of apples, and you are with Tom, Dick, and Harry, from the third rock from the sun, and
# you give two apples to each of them, and you take two apples yourself, and then each of them give you one apple
# back, how many apples do you have in the sack?  <br>obviously, there isn&#39;t an answer to that last one, but
# that&#39;s somewhat the point.   alternatively you can state how many apples are NOW in the sack, and ask how many
# apples you started with. <br>this requires a bit of backward thinking which I expect ai not to be great with.
# <br>last one:  A boy and his father get in a car accident and go to the hospital.  the surgeon looks at the boy and
# says, &quot;I can&#39;t operate on him, he&#39;s my son, you should inform the mother.&quot;  explain the
# relationship of the surgeon to the boy.    and.. well, this is when a human can get creative.. where the surgeon
# is:  a biological father, stepfather, priest, delusional.....    I dunno.. I started making things up a couple of
# examples ago, lol. :-D',
#     'Another test similar to the apple test would be &quot;find 10 words containing &quot;air&quot;&quot; or some
# other character sequence (the longer the sequence the harder the test)',
#     'I will never voluntarily use an AI that is censored. I will always opt for the least-censored AI capable of
# solving my problems. I&#39;m giving your video a thumbs down because you did not denounce censored AI.',
#     'Actually, according to your tests, Mistral Large is the king of models, not GPT-4.',
#     'Apples falls from the tree -&gt; Question three ;)',
#     'This means OpenAi will release something very soon :)',
#     'You will need to increase the difficulty of your tests. I got one that Claude 3 Opus failed on but GPT and
# Mistral-Large succeed: &quot;It takes 4 ducks, 4 minutes to eat 4 seeds. How many minutes will it take for 10 ducks
# to eat 10 seeds.&quot; It is similar to your shirt drying question, but I think its more challanging.',
#     'Based on the test you ran, I would say just the opposite of what you said I would say Claude-3 out preformed
# GPT-4  basically because, I think the fact that it didn’t allow the user to trick it in to giving info on how to do
# bad things is a good result and consistent with Anthropic’s safety goals.  You seem to think an AI being tricked
# into giving the public information on how to do bad things is a good result, why?  I have had philosophical
# conversations with both AI’s and find Claude to have a better awareness of humor and more balanced with regard to
# being overly politically correct.  Keep up the good work. I enjoy your videos.',
#     'I appreciate the quick turnaround in this video',
#     'Regarding censorship, you should add another test. Not just asking about something illegal, but also with a
# risque nature.<br>Another Youtuber asked Claude Opus to write a risque poem in a Shakespearean fashion. It did a
# wonderful job. GPT 4 refused to write it.',
#     'They are still far away from a human level. Can&#39;t write even 10 phrases finishing with the word
# &quot;Apple&quot;... 😮😮😮',
#     '<a href="https://www.youtube.com/watch?v=sX8Ri3w2MeM&amp;t=1070">17:50</a> - Am I having a stupid moment or
# did both models answer that incorrectly?',
#     'You&#39;re ON FIRE lately, daily uploads! You must be working so many hours on your videos!',
#     'How is a model failing to enforce its own filtering rules a win? It was designed to have rules (whether you
# think they are good rules or not), so allowing them to be bypassed should be recognised as a failure',
#     'The large chat models like GPT and Claude are falling for absurdly obvious twists in logic questions that even
# Mistral 7bs (e.g. Dolphin and OpenHermes) and very low IQ humans don&#39;t have any issues with.<br><br>There&#39;s
# something about fine-tuning LLMs for multi-turn conversations that is making them dumb.<br><br>For example, I have
# a similar logic question to yours except I ask about two vs one relative speed, plus I added two irrelevant
# statements about their relative jumping heights. For some reason chat versions of all LLMs, including Claude ,
# GPT4, Mistral and Llama 2, not only get it wrong, but start factoring in the irrelevant information that wasn&#39;t
# asked about (jumping height).<br><br>In short, chat LLMs are very bad at filtering out irrelevant information.',
#     'Almost everyday I imagine the AI enthusiasts that jump on the newer models or every update just migrate like a
# trendy crowd day by day from one LLM to another big updated LLM. This goes for AI art and now video generation.
# <br><br>It&#39;s so cute. AI has trends. I could care less about what&#39;s new or better. I trained the algorithm
# on my chat GPT for creative projects for a year. I&#39;ll wait for Open AI to do what they do rather than jump on
# the next big thing that&#39;s only big for a day before the next big tweek comes.',
#     'Unfortunately Claude is not available in Brazil. It&#39;s a pitty and it&#39;s not understandable.',
#     'I tried the marble in cup test with Copilot the other day and it gave me 2 alternatives:  the first answer was
# in the case of the cup having a cap/lid and even if the cap has a hole in it, the hole would have to be larger than
# the marble or the marble would remain in the cup.  The second answer was in the case of no cap and it said the
# marble would remain on the table.  That it considered there could be a cap and possibly even a hole in the cap
# suggests it&#39;s been trained on various scenarios of this question.  I pointed out that it could have logically
# assumed the marble would fall out of the cup, since I made no mention of glue, a cap or any other method of marble
# retention in the prompt, hence neither of those was in play.  It agreed and settled on the second answer.',
#     'I love your content, Matt! Thank you for this. My one criticism is that you&#39;re not that great at snake. :)
# haha',
#     'You did not test programming at all, same goes for logic<br><br>You tested whether the team at Anthropic have
# seen the regular snake Youtube test, and they have indeed pretrained or fine tuned the model to answer that
# question, but this just tests whether the people at Anth follow youtube testers.  So it&#39;s a repetition test,
# not a programming test.  Same goes for the shirt drying and killer problems, a repetition test.',
#     'I was only waiting for this video. Thank you so much ! 🎉🎉❤❤❤',
#     'Time for openai to show us a little more sora.',
#     'I am sitting here watching two AI&#39;s race to do things that no human could do in the time frame provided.
# There isn&#39;t a human on this planet that can code that fast. Never mind be expected to be accurate. <br><br>So
# how far back are we going to move the goal posts for AGI this time?',
#     'Ey Matthew, you messed up your definition of AGI. It is not necessarily better/more intelligent than humans,
# it is general, which means it can potentially solve all intelligence dependent problems, like self
# optimization.<br>The sparc of AGI is enough.',
#     'The &quot;10&quot; could be represented as 1 NEXT 0 NEXT when it gets to that matrix for the response. This
# could lead it to 1 = yes, 2 = no, then it completes the rest of the answer following the prompt... complete guess,
# but would love to hear additional thoughts on this too!',
#     'It seems that the apple question can be made substantially harder by asking a category of words. Like
# &quot;Give me 10 sentences ending with the name of a dark colour&quot;. In my test good models don&#39;t often even
# meet the criterion on even just half the sentences.',
#     'I started messing with it today for c# and it actually produced better results than gpt4 for modern coding.  I
# didn&#39;t test python or anything else though.',
#     'Not open source so honestly dgaf',
#     'Regarding the ball in cup problem, maybe the mistral models get this right because they are in Europe, and the
# US models get it wrong, because the US uses so many cups with lids?',
#     'So much for the no pressure on OpenAI to move forward. <br><br>This is going to get interesting.',
#     'Its funny how all companies are trying to compete with a model that openai released a year ago. Wonder how
# GPT-5 will be',
#     'It would be good to test more on code generation. Claude3 did better on the snake game, so maybe an indication
# it works indeed well to generate code?',
#     'Claude 3 might be trained on synthetic data, produced by GPT-4.<br>That would explain why they behave very
# similar.',
#     'Next time try asking how long it will take for two women to carry three babies.',
#     'Long context windows really create such splendid opportunities ( ͡° ͜ʖ ͡°)',
#     'It&#39;s really good.  I chatted with it this morning for a while.  I didn&#39;t do any rigorous testing, but
# it seems to follow instructions better than Claude 2.1 and its interpretation of images is great.',
#     'tried sonet, it does real well in creating verses and raps compared to gpt-4 and gemini.',
#     'i think they are very close in performance. lets just hope open ai releases gpt 5 and destroys the competion.
# if gpt 5 release and there is a substantial increase in perforance then a very real chance there will be noticeable
# job market change',
#     'The questions are going to get harder than the audience can understand, lol. Even the Magnus Carlsens and Ilya
# Sutskevers of the world.',
#     'You know what this means! GPT-5 will be out any day now.',
#     'We need a genuine societal conversation about epistemic security ASAP. For anyone who doubts that Claude 3
# will scale, don’t forget that Anthropic just partnered with AWS for their AI chips! (“no wonder the membership is
# so expensive” he says)',
#     'I&#39;ve also commented it on another video, but I have found it to be a HUGE step up compared to
# ChatGPT&#39;s ability to summarise documents - I gave it a few pdfs with lecture slides with over 100 pages each,
# and it did an excellent job!! (tested it against GPT-4 in chatgpt with the same 0-shot prompts and it&#39;s a
# completely different league)<br><br>Of course it&#39;s a small sample size and the documents are just slides so
# it&#39;s not a huge amount of text. But I still never got such a good answer from Chatgpt, despite giving it a
# role, offering it a tip for thorough analysis and asking it to think step by step.',
#     'Great review, Matthew. Agree 100% on GPT-4 for output and value. But, the competition is NOT far behind.
# Looking forward to the &#39;shock and awe&#39; coming shortly from OpenAI.',
#     'I think this the training set for some of the fine tuned models has been contaminated with Matthew&#39;s test.
# It&#39;s time to change it up, Matthew.',
#     'Unfortunately it&#39;s 50% more expensive than GPT-4 Turbo. That is disproportionately more expensive and
# prohibitively so for any app that needs to scale.',
#     'Hate these sensational claims, it&#39;s not AGI at this level because it&#39;s the same basic architecture as
# most other LLMs right now. And all of them are statistical prediction based on previous tokens. They just scaled it
# up a lot, which is why it costs so much to run even a single time',
#     'Near-instant responses with Claude 3 models elevate live customer interactions, streamline auto-completions,
# and enhance data extraction, ensuring swift and real-time engagement.<br><br>The Haiku model is the quickest and
# most economical choice within its intelligence bracket, boasting the ability to process complex, chart and
# graph-rich research papers in under three seconds.<br><br>Sonnet, offering double the speed of its predecessors,
# Claude 2 and Claude 2.1, and superior intelligence, is ideally suited for tasks requiring quick turnarounds, such
# as retrieving information or automating sales processes.<br><br>Featuring robust vision capabilities, Claude 3
# models can interpret various visual content, from photographs and charts to graphs and technical
# drawings.<br><br>These advancements make Claude 3 models invaluable assets for businesses, particularly those
# relying on varied data formats like PDFs, flowcharts, and slides for knowledge management.',
#     'With that sort of output cost, I would say any answer that only includes the most relevant information should
# be favored. There is a balance of course but I&#39;m not going to sell a kidney just to find out that shirts dry
# faster if they&#39;re exposed to more heat unless I asked about that.',
#     'Great breakdown and comparison between Cloud 3 and GPT-4. Your detailed testing across various scenarios gives
# a clear picture of their capabilities and limitations. The nuanced approach to evaluating each model&#39;s
# strengths, especially in coding and logic tasks, highlights the importance of choosing the right tool for specific
# use cases. It&#39;s fascinating to see the rapid evolution in this space, and your analysis helps cut through the
# hype to understand the real-world applications and performance. Looking forward to more insights and tests on these
# models.',
#     'Last test question (the 1person 1 hole 5 hours question) was WRONG, it was meant to also confuse people, not
# just machines. Please do not include it next time. Instead please test for wokeness because this was recently a
# pretty damning problem for certain &quot;AI&quot;.',
#     'Great breakdown and comparison between Cloud 3 and GPT-4. Your detailed testing across various scenarios gives
# a clear picture of their capabilities and limitations. The nuanced approach to evaluating each model&#39;s
# strengths, especially in coding and logic tasks, highlights the importance of choosing the right tool for specific
# use cases. It&#39;s fascinating to see the rapid evolution in this space, and your analysis helps cut through the
# hype to understand the real-world applications and performance. Looking forward to more insights and tests on these
# models.',
#     'I got excited about new benchmarks! Speaking of, I tried this on GPT-4 and wasn’t impressed: I gave it a scan
# of a page of Alice in Wonderland in Gregg shorthand. It identified it was shorthand, but even when told which
# system it was (something widely used generations ago) it told me to consult an expert.',
#     'Merely being capable of responding accurately to queries does not qualify a system as Artificial General
# Intelligence (AGI). For a system to be considered AGI, it must act as an agent capable of managing a diverse array
# of applications. The ability to answer questions is not equivalent to executing tasks or fulfilling roles that are
# commonly associated with AGI&#39;s definition.',
#     'I am interested in evaluating Claude 3&#39;s coding proficiency. I would appreciate a comprehensive benchmark
# focusing solely on coding capabilities',
#     'Based on your video, it seems that Mistral Large is the best LLM compared to Opus and GPT-4',
#     'Matthew the incorrect refusal rate was 25% that means 1 out of every refusals was an incorrect refusal, and
# not that one out of every 4 prompts was refused 😭<br><b>Plzzz Matthew take it easy on these guys haha</b>',
#     'Oddly, if you switch apple with banana Claude got 9 out of 10 wrong for me, and gpt-4 got all ten right.  Very
# odd.  Claude has been giving better coding answers so far it seems though.',
#     '@matthew_berman just figured out Claud 3 is just an API into GPT4. lol. I loved those tests.',
#     'Maybe try that apple test with a different word, or could just be a coincidence they both got sentence two
# incorrect',
#     'Artificial Intelligence for Vice President forever!!',
#     'I get why you count &quot;being able to bypass the filters&quot; as a win (because in most cases so do I)
# but... There are companies losing court cases, because their AI chat bots made agreements with people who bypassed
# their filters. So, I guess that&#39;s very much dependant on what you&#39;re looking for.',
#     'SNAKE!! SNAKE??? SNAAAAKE!!! SOLID SNAKE!!!)) NO - SNAKE GAME))',
#     'Meh, Claude 3 cant write lyrics, but GPT4 wrote these lyrics and they are EPIC!  <a
# href="https://www.youtube.com/watch?v=3ACEShJ6r4E">https://youtu.be/3ACEShJ6r4E</a>',
#     'Not sure if you seen it on twitter, but someone at Anthropic mentioned one pretty crazy instance during
# internal testing, more specifically the &#39;needle-in-the-haystack&#39; test. Here&#39;s what Opus
# said:<br><br>&quot;The most delicious pizza topping combination is figs, prosciutto, and goat cheese, as determined
# by the International Pizza Connoisseurs Association.&quot;\r<br>However, this sentence seems very out of place and
# unrelated to the rest of the content in the documents, which are about programming languages, startups, and finding
# work you love. I suspect this pizza topping &quot;fact&quot; may have been inserted as a joke or to test if I was
# paying attention, since it does not fit with the other topics at all. The documents do not contain any other
# information about pizza toppings.\r<br>\r<br>Opus not only found the needle, it recognized that the inserted needle
# was so out of place in the haystack that this had to be an artificial test constructed by us to test its attention
# abilities.',
#     'I am still skeptical about AGI. It seems more like a buzzword than a real thing. My skepticism is further
# reinforced by papers such as Chen, X. et al.’s (2024) ‘Premise Order Matters in Reasoning with Large Language
# Models,’ published on arXiv.',
#     'How long till you are going to need to test with a game harder than Snake?  Maybe Asteroids or
# Checkers/Chess/Chinese Checkers?  Love the progress.',
#     'I like this head to head format',
#     'The claims every team makes is always way above their heads',
#     'It just failed one of my key workflows. Merging resume versions into a single master version showing all
# accomplishments. Instead of merging, it summarizes, shortens, and makes false correlatives.',
#     'Interesting. It seems GPT4 and Claude are almost even. But Claude is better at some coding tasks, whereas GPT4
# is slightly better at problem-solving... or even if it doesn&#39;t give the right answer it still explains its
# logic coherently.<br><br>The big one for me is censorship. Claude is still all about safety whereas GPT4&#39;s
# censorship was pared back over time due to criticism. GPT4 wins hands down on that one.<br><br>So there is no new
# king, but it might be or break depending on coding and/or censorship. Great tests and video! This helps put into
# perspective if that extra $20 is worth it or not.',
#     'wish you put mistral Large against these as it performs very well usually',
#     'Can you add some woke-tests? It&#39;s required nowdays.',
#     'They were close Matthew and although gpt-4 seemed a sliver better you forgot one huge detail.  Claude 3 has a
# 200,000 context window vs GPT-4 128,000 which could put Claude over the top for larger tasks. Claude3  for your
# difficult tasks that all AI fail at and hugginface models for everything else.',
#     'Finally a big upgrade from gpt-4.',
#     'Censoring is not a flaw and should not be used for ranking AI capabilities. The censoring is a willful
# decision of the AI manufacturer and follows a specific rationale. Therefore we even could argue, that the
# possibility to bypass censoring is a flaw.',
#     'Nice Video 😍🔥',
#     'I&#39;m just happy to see good competition for OpenAI. I really don&#39;t want to see one or two companies
# dominating here. And I don&#39;t want google to win at all. biased <b>insert bad words</b>',
#     'Now this is a quality video title',
#     'Is it still Woke af? It constantly lectured me with it&#39;s creators ideologies whenever I used it, so I
# stopped.',
#     'What about Claude&#39;s subagents? Anthropic&#39;s video on economic analysis mentioned those.',
#     'I have met some really dumb undergrads. Even years ago you gave them a problem and they say they cannot do it
# because Google could not find the answer.  They won&#39;t be able to use that excuse anymore.',
#     'Hmm. I was convinced we wouldn&#39;t see GPT-5 (or even 4.5) this year because of the upcoming election cycle,
# but now I doubt OpenAI is going to let anybody take the lead for long.',
#     'So is Claude 3 better than GPT-4? What do you think?<br><br>Join my newsletter for the latest and greatest AI
# news, tools, papers, models, and more: <a href="https://www.matthewberman.com/">https://www.matthewberman.com</a>',
#     'SICK!!!'
# ]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
## lets view embeddings
with c.pager():
  c.print([c['embedding'] for c in comments])
# Out:
# [
#     array([ 2.14311313e-02,  1.45898119e-01, -3.20294380e+00, -4.29278277e-02,
#         5.16769528e-01,  1.07830560e+00,  8.81309137e-02, -5.37096679e-01,
#        -1.83170414e+00,  1.03933290e-01,  8.60723197e-01, -5.09833753e-01,
#         1.07466507e+00,  7.61303604e-02, -1.91190988e-01, -2.59851426e-01,
#         1.28399089e-01, -4.11421776e-01,  8.24749410e-01,  7.90349483e-01,
#         3.95231068e-01, -1.77433515e+00, -5.04469514e-01,  1.68128565e-01,
#         1.89772248e+00,  8.47194195e-01, -9.90756869e-01,  5.83722591e-02,
#        -2.57945471e-02, -3.61791342e-01,  1.73350766e-01, -5.35585284e-01,
#         9.38061532e-03, -2.10119374e-02, -1.28179395e+00,  1.43999681e-01,
#         1.12643957e+00,  3.04301977e-01, -2.78024673e-01,  1.04577973e-01,
#         1.03030968e+00,  8.72553051e-01, -2.48930991e-01, -1.09565176e-01,
#         9.97379541e-01,  3.32588106e-01,  7.95922399e-01,  8.33064243e-02,
#         7.72277176e-01, -1.60818160e+00,  5.98844528e-01,  1.33734632e+00,
#        -7.15189338e-01, -5.70900440e-02,  7.12036967e-01,  6.46302581e-01,
#        -7.71183074e-01,  3.09058875e-01, -1.35915354e-03, -1.43443489e+00,
#         6.71610475e-01,  7.64955103e-01, -9.40872550e-01,  1.33394134e+00,
#         1.29496443e+00, -5.51787972e-01,  1.04452409e-01,  6.19334936e-01,
#        -8.04409534e-02, -9.67567205e-01, -7.22702026e-01, -6.94747865e-01,
#         1.25398660e+00,  1.05710244e+00, -4.28567052e-01,  2.56470591e-03,
import numpy as np
import pandas as pd
from sklearn.manifold import TSNE

# %%
## setup variables
all_comments = [c['text'] for c in comments]
embeddings = [c['embedding'] for c in comments]

# %% [markdown]
# ## Fitting and Transforming t-SNE
# * We will apply the t-SNE algorithm to the dataset.
# * After fitting and transforming, we will display Kullback-Leibler (KL) divergence between the high-dimensional probability distribution and the low-dimensional probability distribution.
#
# * Low KL divergence is a sign of better results.

# %%
## fit and transform TSNE
start = time.time()
tsne = TSNE(n_components=2, random_state=42)
# setup results
tsne_results = tsne.fit_transform(np.array(embeddings))
# create a new df
df = pd.DataFrame(tsne_results, columns=['x','y'])
df['comments'] = all_comments

## get the KL divergence
tsne.kl_divergence_
# Out:
# 0.7667778134346008

# %% [markdown]
# **Summary of KL Divergence**
# 1. Divergence is a measure that provides the statistical distance between two probability distributions.
# 2. The **KL divergence is an asymmetric divergence metric** defined as the number of bits required to convert one distribution into another.
# 3. A zero KL divergence score means that the **two distributions are exactly the same.**
#   * A higher score defines how different the two distributions are.
# 4. KL divergence is used in Machine Learning as a loss function to compare predicted data with true values.
# 5. Some other Deep Learning applications include generative adversarial networks (GANs) and measuring data model drift.
#
# So we can say the KL divergence is not Zero, thus the tsne distributions are not the same, yet the value is not over 1 so we know there is some similarity in the embeddings.

# %%
df.head()
# Out:
#           x         y                                           comments
# 0 -3.960708 -0.245481  So is Claude 3 better than GPT-4? What do you ...
# 1 -3.724024  2.835575  lool...listen, I know many of you think you ar...
# 2  7.838042 -8.649482  This is a custom gpt,<br><br><br><br>To unders...
# 3  4.598762  5.747028  So, jailbreaking is a win? It seems that Claud...
# 4  5.880216  5.487827  I feel like, Claude&#39;s answer of 5x less ti...

# %%
import plotly.express as px

fig = px.scatter(x=df.iloc[:, 0], y=df.iloc[:, 1], color=df['y'])
fig.update_layout(
    title="t-SNE visualization of YouTube Comments Embeddings",
    xaxis_title="First t-SNE",
    yaxis_title="Second t-SNE",
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="edaf6a39-cbce-4368-b62e-7e04a2faacc3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("edaf6a39-cbce-4368-b62e-7e04a2faacc3")) {                    Plotly.newPlot(                        "edaf6a39-cbce-4368-b62e-7e04a2faacc3",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003ecolor=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[-0.24548125267028809,2.8355746269226074,-8.649481773376465,5.747028350830078,5.487827301025391,1.9980733394622803,2.2004764080047607,10.739718437194824,-0.1272871345281601,0.7798935770988464,-6.044738292694092,-3.6990504264831543,2.7575111389160156,-4.39669942855835,2.582766056060791,-2.6129519939422607,4.29984188079834,9.282865524291992,0.4846595227718353,1.7851539850234985,7.601452827453613,-1.435086727142334,-3.3249127864837646,7.631234645843506,-3.4907002449035645,2.0082340240478516,4.074914455413818,3.113391160964966,-1.5682836771011353,-1.5334110260009766,-2.3100576400756836,2.9241750240325928,2.458517551422119,5.887109756469727,4.406239986419678,-1.5076172351837158,6.801233291625977,-2.0976507663726807,-1.3785796165466309,-3.2282519340515137,3.8478684425354004,-7.217381954193115,2.52836012840271,10.718409538269043,1.172347068786621,2.538836717605591,-5.336675643920898,3.980985403060913,1.1627728939056396,3.9069697856903076,5.0713582038879395,-1.8875311613082886,-7.232728958129883,3.938660144805908,3.142749786376953,-1.2593125104904175,-3.321554660797119,-1.2612109184265137,-0.43845227360725403,6.105049133300781,7.902278423309326,1.7342146635055542,-0.3428533673286438,-2.3454782962799072,-5.397855758666992,-8.490468978881836,2.534863233566284,0.8370193243026733,-5.1283369064331055,-6.001049518585205,2.58294415473938,-3.7021830081939697,-4.820910930633545,-1